# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


data1 = pd.read_csv('HSA-Tensile-Torsion_1.csv')
data2 = pd.read_csv('HSA-Tensile-Torsion_2.csv')

# %%
plt.plot(data1['Displacement'], data1['Force']*(-1))
plt.plot(data2['Displacement'], data2['Force']*(-1))
plt.title("Force Displacement Data")
plt.figure()
plt.plot(data1['Rotation']*(-1), data1['Force']*(-1))
plt.plot(data2['Rotation']*(-1), data2['Force']*(-1))
plt.title("Force Rotation Data")
# Out:
# Text(0.5, 1.0, 'Force Rotation Data')
